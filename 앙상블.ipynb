# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
import xgboost as xgb
import lightgbm as lgb
from sklearn.svm import SVR
from sklearn.datasets import make_regression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor

# %%
def mape(y_true, y_pred): 
       y_true, y_pred = np.array(y_true), np.array(y_pred)
       return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
import keras
class PrintDot(keras.callbacks.Callback):  
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')
early_stop = keras.callbacks.EarlyStopping(monitor='loss', patience=10)          
def MAE(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred)))    
def sMAPE(y_true, y_pred): 
       y_true, y_pred = np.array(y_true), np.array(y_pred)
       return np.mean(np.abs((y_true - y_pred) / (y_true + y_pred))) * 200

# %%
a = !ls
a
# Out:
# ['~$理쒖쥌.xlsx',
#  '1_�긽紐�_33.03_2D_oneConv2Dlayer.csv',
#  '1_�긽紐�_33.03_2D_oneConv2Dlayer_2020.csv',
#  '1_李쏀씗_34.17_DNNelu.csv',
#  '1_李쏀씗_34.17_DNNelu_2020.csv',
#  '1_�븯�뒛_gbrt_34.050180776792324_n_1000_max_depth_22_min_samples_leaf_30_random_state_10.csv',
#  '1_�븯�뒛_gbrt_34.050180776792324_n_1000_max_depth_22_min_samples_leaf_30_random_state_10_2020.csv',
#  '1_�븯�뒛_lgbm_34.80054451098967_num_leaves_15_learing_Rate_0.4_n_1000_max_bin_75_feature_fraction_seed=13.csv',
#  '1_�븯�뒛_lgbm_34.80054451098967_num_leaves_15_learing_Rate_0.4_n_1000_max_bin_75_feature_fraction_seed=13_2020.csv',
#  '1_�븯�뒛_rf_36.904097243505056_n_500_random_state_77.csv',
#  '1_�븯�뒛_rf_36.904097243505056_n_500_random_state_77_2020.csv',
#  '1_�븯�뒛_xgboost_33.812667441702054_max_depth_7_n_1000_random_state_7.csv',
#  '1_�븯�뒛_xgboost_33.812667441702054_max_depth_7_n_1000_random_state_7_2020.csv',
#  '10_�긽紐�_30.46_CNN_3D_twoConv2Dlayers_with_embedding_largeepoch.csv',
# ...

# %%
sang1_2d ='1_상명_32.56_CNN_2D_oneConv2Dlayer.csv'

# %%
data = pd.read_csv('최종0927.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('취급액', axis=1), data['취급액'], test_size=0.2, random_state=42)

# %%
for i in range(len(a)):
    if '�긽紐�' in a[i]:
        a[i] = a[i].replace('�긽紐�','상명')
    elif '�븯�뒛' in a[i]:
        a[i] = a[i].replace('�븯�뒛','하늘')
    elif '李쏀씗' in a[i]:
        a[i] = a[i].replace('李쏀씗','창희')

# %%
a
# Out:
# ['~$理쒖쥌.xlsx',
#  '1_상명_33.03_2D_oneConv2Dlayer.csv',
#  '1_상명_33.03_2D_oneConv2Dlayer_2020.csv',
#  '1_창희_34.17_DNNelu.csv',
#  '1_창희_34.17_DNNelu_2020.csv',
#  '1_하늘_gbrt_34.050180776792324_n_1000_max_depth_22_min_samples_leaf_30_random_state_10.csv',
 '5_상명_33.59_3D_twoConv2Dlayers_epoch250.csv',
 '5_하늘_gbrt_34.1190641250589_n_1000_max_depth_40_min_samples_leaf_35_min_samples_split_10.csv',
 '5_하늘_lgbm_34.05990264001836_n_1000_max_bin_75_bagging_freq_7.csv',
 '5_하늘_xgboost_33.61607811534924_gamma_0.05_max_depth_7_n_1000.csv',
 '6_상명_32.19_CNN_3Ddiffimgsize_oneConv2Dlayer_filter_3,3.csv',
 '6_하늘_gbrt_33.11273129842049_n_1000_max_depth_25_min_samples_leaf_30_min_samples_split_15.csv',
 '6_하늘_lgbm_34.194726841659026_num_leaves_10_n_1000_max_bin_70_bagging_freq_9.csv',
 '6_하늘_xgboost_33.23394573418041_max_depth_7_n_1300.csv',
 '7_상명_31.36_CNN_with_JJinsangpoom_embedding_maxpooling.csv',
 '7_하늘_gbrt_33.032996171577466_n_1000_max_depth_35_min_samples_leaf_35.csv',
 '7_하늘_lgbm_33.40126527279879_n_1500_max_bin_70_bagging_freq_7.csv',
 '7_하늘_xgboost_33.123012504239306_max_depth_12_n_1000.csv',
 '8_상명_30.00_CNN_2D_with_embedding_epoch250_nomax.csv',
 '8_하늘_gbrt_33.09348956234671_n_1000_max_depth_35_min_samples_leaf_35.csv',
 '8_하늘_lgbm_33.726979950748515__n_1500_max_bin_70_bagging_freq_9_min_data_in_leaf_1.csv',
 '8_하늘_xgboost_33.07747030509739_gamma_0.005_n_800.csv',
 '9_상명_30.14_CNN_3D_with_embedding.csv',
 '9_하늘_xgboost_33.58199968983337_gamma_0.05_n_1000.csv']

# %%
b = np.array(pd.read_csv(a[0])['0'])
for i in range(1,len(a)):
    b += np.array(pd.read_csv(a[i])['0'])
pred1 = b/len(a)
mape(np.exp(np.array(y_test)), b/len(a))
# Out:
# 30.780927123901836

# %%
final= ['9_상명_30.14_CNN_3D_with_embedding.csv', '7_상명_31.36_CNN_with_JJinsangpoom_embedding_maxpooling.csv',
     '8_상명_30.00_CNN_2D_with_embedding_epoch250_nomax.csv','8_상명_30.00_CNN_2D_with_embedding_epoch250_nomax.csv','1_창희_34.17_DNNelu.csv',
     '11_상명_30.68_CNN_2D_oneConv2Dlayer_with_embedding_filter_3,2.csv',
 '11_하늘_xgboost_32.39425483045724_gamma_0.005_max_depth_12_n_800.csv',
 '12_상명_30.68_CNN_3D_oneConv2Dlayer_with_embedding_largeepoch.csv','13_상명_30.22_CNN_3D_Conv2Dlayer&Conv1Dlayer_with_embedding.csv',
     
    ]

# %%
b = np.array(pd.read_csv(final[0])['0'])
for i in range(1,len(final)):
    b += np.array(pd.read_csv(final[i])['0'])
pred1 = b/len(a2)
mape(np.exp(np.array(y_test)), b/len(final))
# Out:
# 28.73137298539246

# %%
finalsubmit= ['9_상명_30.14_CNN_3D_with_embedding_2020.csv', '7_상명_31.36_CNN_with_JJinsangpoom_embedding_maxpooling_2020.csv',
     '8_상명_30.00_CNN_2D_with_embedding_epoch250_nomax_2020.csv','8_상명_30.00_CNN_2D_with_embedding_epoch250_nomax_2020.csv','1_창희_34.17_DNNelu_2020.csv',
     '11_상명_30.68_CNN_2D_oneConv2Dlayer_with_embedding_filter_3,2_2020.csv',
 '11_하늘_xgboost_32.39425483045724_gamma_0.005_max_depth_12_n_800_2020.csv',
 '12_상명_30.68_CNN_3D_oneConv2Dlayer_with_embedding_largeepoch_2020.csv','13_상명_30.22_CNN_3D_Conv2Dlayer&Conv1Dlayer_with_embedding_2020.csv',
     
    ]

# %%
b = np.array(pd.read_csv(finalsubmit[0])['0'])
for i in range(1,len(finalsubmit)):
    b += np.array(pd.read_csv(finalsubmit[i])['0'])
pred1 = b/len(finalsubmit)

# %%
pd.DataFrame(pred1).to_excel('최종.xlsx')

# %%
test = pd.read_excel('test.xlsx')

# %%
test['Unnamed: 7'] = ['취급액'] + list(pred1)

# %%
pred1.mean()
# Out:
# 23120425.60603361

# %%
pred1.mean()
# Out:
# 13324551.58975615

# %%
test
# Out:
#      NS Shop+ 2020년 6월 편성 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    방송일시      노출(분)       마더코드       상품코드
# 1     2020-06-01 06:20:00         20     100650     201971
# 2     2020-06-01 06:40:00         20     100650     201971
# 3     2020-06-01 07:00:00         20     100650     201971
# 4     2020-06-01 07:20:00         20     100445     202278
# ...                   ...        ...        ...        ...
# 2887  2020-07-01 00:20:00         20     100660     201989
# 2888  2020-07-01 00:40:00         20     100660     201989
# 2889  2020-07-01 01:00:00         20     100660     201989
# 2890  2020-07-01 01:20:00         20     100261     200875
# 2891  2020-07-01 01:40:00    15.9333     100261     200875
#
#                 Unnamed: 4 Unnamed: 5 Unnamed: 6   Unnamed: 7
# 0                      상품명        상품군       판매단가          취급액
# 1          잭필드 남성  반팔셔츠 4종         의류      59800  3.29235e+06
# 2          잭필드 남성  반팔셔츠 4종         의류      59800  5.91599e+06
# ...

# %%
for i in range(len(test)):
    if test.iloc[i,:]['Unnamed: 6'] == 0:
        test.iloc[i,:]['Unnamed: 7'] = 0
test
# Out:
#      NS Shop+ 2020년 6월 편성 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    방송일시      노출(분)       마더코드       상품코드
# 1     2020-06-01 06:20:00         20     100650     201971
# 2     2020-06-01 06:40:00         20     100650     201971
# 3     2020-06-01 07:00:00         20     100650     201971
# 4     2020-06-01 07:20:00         20     100445     202278
# ...                   ...        ...        ...        ...
# 2887  2020-07-01 00:20:00         20     100660     201989
# 2888  2020-07-01 00:40:00         20     100660     201989
# 2889  2020-07-01 01:00:00         20     100660     201989
# 2890  2020-07-01 01:20:00         20     100261     200875
# 2891  2020-07-01 01:40:00    15.9333     100261     200875
#
#                 Unnamed: 4 Unnamed: 5 Unnamed: 6   Unnamed: 7
# 0                      상품명        상품군       판매단가          취급액
# 1          잭필드 남성  반팔셔츠 4종         의류      59800  3.29235e+06
# 2          잭필드 남성  반팔셔츠 4종         의류      59800  5.91599e+06
# ...

# %%
test.to_excel('최종결과제출.xlsx')
